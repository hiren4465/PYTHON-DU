# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(121)
data = np.random.randint(1,100,(5,4))
data
# Out:
# array([[67, 86,  9, 96],
#        [66, 53, 84, 97],
#        [47, 35, 53, 61],
#        [55,  4, 95, 53],
#        [58, 76, 89, 40]])

# %%
subjects = ['PDS','CN','ADA','SE']

# %%
rollno = np.arange(101,106)
rollno
# Out:
# array([101, 102, 103, 104, 105])

# %%
stu = pd.DataFrame(data,rollno,subjects)

# %%
stu>35
# Out:
#       PDS     CN    ADA    SE
# 101  True   True  False  True
# 102  True   True   True  True
# 103  True  False   True  True
# 104  True  False   True  True
# 105  True   True   True  True

# %%
tempdf = stu>35

# %%
stu[tempdf]
# Out:
#      PDS    CN   ADA  SE
# 101   67  86.0   NaN  96
# 102   66  53.0  84.0  97
# 103   47   NaN  53.0  61
# 104   55   NaN  95.0  53
# 105   58  76.0  89.0  40

# %% [markdown]
# <h1>setting / resetting index</h1>

# %%
stu.reset_index()
stu.index.name = "Roll no"
stu
# Out:
#          PDS  CN  ADA  SE
# Roll no
# 101       67  86    9  96
# 102       66  53   84  97
# 103       47  35   53  61
# 104       55   4   95  53
# 105       58  76   89  40

# %%
# for make ADA index

stu.set_index("ADA")
# Out:
#      PDS  CN  SE
# ADA
# 9     67  86  96
# 84    66  53  97
# 53    47  35  61
# 95    55   4  53
# 89    58  76  40

# %%
stu.reset_index()
# Out:
#    Roll no  PDS  CN  ADA  SE
# 0      101   67  86    9  96
# 1      102   66  53   84  97
# 2      103   47  35   53  61
# 3      104   55   4   95  53
# 4      105   58  76   89  40

# %%
stu
# Out:
#          PDS  CN  ADA  SE
# Roll no
# 101       67  86    9  96
# 102       66  53   84  97
# 103       47  35   53  61
# 104       55   4   95  53
# 105       58  76   89  40

# %%
stu.reset_index(inplace=True)

# %%
stu
# Out:
#    Roll no  PDS  CN  ADA  SE
# 0      101   67  86    9  96
# 1      102   66  53   84  97
# 2      103   47  35   53  61
# 3      104   55   4   95  53
# 4      105   58  76   89  40

# %%
stu.index.name ="ADA"

# %%
stu
# Out:
#      Roll no  PDS  CN  ADA  SE
# ADA
# 0        101   67  86    9  96
# 1        102   66  53   84  97
# 2        103   47  35   53  61
# 3        104   55   4   95  53
# 4        105   58  76   89  40

# %%
df = pd.read_csv("MultiIndexDemo.csv")
df
# Out:
#        Col Dep  Sem   RN    S1    S2    S3
# 0      ABC  CE    5  101  56.0  56.0  56.0
# 1      ABC  CE    5  102  54.0  54.0  54.0
# 2      ABC  CE    7  101  43.0  43.0  43.0
# 3      ABC  ME    5  101  38.0  38.0  38.0
# 4      ABC  ME    5  102  31.5  31.5  31.5
# 5  Darshan  CE    5  101  25.0  25.0  25.0
# 6  Darshan  CE    5  102  18.5  18.5  18.5
# 7  Darshan  CE    7  101  12.0  12.0  12.0
# 8  Darshan  ME    5  101   5.5   5.5   5.5

# %%
df.set_index(['Col','Dep','Sem','RN'],inplace=True)

# %%
df
# Out:
#                        S1    S2    S3
# Col     Dep Sem RN
# ABC     CE  5   101  56.0  56.0  56.0
#                 102  54.0  54.0  54.0
#             7   101  43.0  43.0  43.0
#         ME  5   101  38.0  38.0  38.0
#                 102  31.5  31.5  31.5
# Darshan CE  5   101  25.0  25.0  25.0
#                 102  18.5  18.5  18.5
#             7   101  12.0  12.0  12.0
#         ME  5   101   5.5   5.5   5.5

# %%
df.loc['ABC','CE',5,102]
# Out:
# S1    54.0
# S2    54.0
# S3    54.0
# Name: (ABC, CE, 5, 102), dtype: float64

# %%
hf = pd.read_csv("MultiIndexDemo.csv",index_col=[0,1,2,3])
hf
# Out:
#                        S1    S2    S3
# Col     Dep Sem RN
# ABC     CE  5   101  56.0  56.0  56.0
#                 102  54.0  54.0  54.0
#             7   101  43.0  43.0  43.0
#         ME  5   101  38.0  38.0  38.0
#                 102  31.5  31.5  31.5
# Darshan CE  5   101  25.0  25.0  25.0
#                 102  18.5  18.5  18.5
#             7   101  12.0  12.0  12.0
#         ME  5   101   5.5   5.5   5.5

# %%
np.random.seed(121)
data=np.random.randint(1,100,25).reshape(5,5)
data
# Out:
# array([[67, 86,  9, 96, 66],
#        [53, 84, 97, 47, 35],
#        [53, 61, 55,  4, 95],
#        [53, 58, 76, 89, 40],
#        [22, 42, 56, 84, 95]])

# %%
i=[101,102,103,104,105]

# %%
c = ['a','b','c','d','e']

# %%
d = pd.DataFrame(data,i,c)
d
# Out:
#       a   b   c   d   e
# 101  67  86   9  96  66
# 102  53  84  97  47  35
# 103  53  61  55   4  95
# 104  53  58  76  89  40
# 105  22  42  56  84  95

# %%
f = d[d>35]
f
# Out:
#         a   b     c     d     e
# 101  67.0  86   NaN  96.0  66.0
# 102  53.0  84  97.0  47.0   NaN
# 103  53.0  61  55.0   NaN  95.0
# 104  53.0  58  76.0  89.0  40.0
# 105   NaN  42  56.0  84.0  95.0

# %%
f.dropna()
# Out:
#         a   b     c     d     e
# 104  53.0  58  76.0  89.0  40.0

# %%
f
# Out:
#         a   b     c     d     e
# 101  67.0  86   NaN  96.0  66.0
# 102  53.0  84  97.0  47.0   NaN
# 103  53.0  61  55.0   NaN  95.0
# 104  53.0  58  76.0  89.0  40.0
# 105   NaN  42  56.0  84.0  95.0

# %%
f.fillna("35")
# Out:
#         a   b     c     d     e
# 101  67.0  86    35  96.0  66.0
# 102  53.0  84  97.0  47.0    35
# 103  53.0  61  55.0    35  95.0
# 104  53.0  58  76.0  89.0  40.0
# 105    35  42  56.0  84.0  95.0

# %%
f.interpolate(limit_direction='backward')
# Out:
#         a   b     c     d     e
# 101  67.0  86  97.0  96.0  66.0
# 102  53.0  84  97.0  47.0  80.5
# 103  53.0  61  55.0  68.0  95.0
# 104  53.0  58  76.0  89.0  40.0
# 105   NaN  42  56.0  84.0  95.0

# %%
f.interpolate(limit=90)
# Out:
#         a   b     c     d     e
# 101  67.0  86   NaN  96.0  66.0
# 102  53.0  84  97.0  47.0  80.5
# 103  53.0  61  55.0  68.0  95.0
# 104  53.0  58  76.0  89.0  40.0
# 105  53.0  42  56.0  84.0  95.0

# %%
ah = pd.read_excel("Studentdata.xlsx",index_col=[0,1,2,3])

# %%
ah
# Out:
#                      SPI
# Col     Dep Sem RN
# ABC     CE  5   101  9.3
#                 102  4.3
#                 103  3.4
#             7   101  3.5
#                 102  3.4
#         EE  5   101  5.6
#                 102  6.7
#             7   101  5.6
#         IT  5   101  5.5
#             7   101  4.4
# Darshan IT  5   101  9.9
#             7   101  8.1
#         CE  5   101  9.7
#                 102  8.1
#             7   101  9.4
#         EE  5   101  8.1
#                 102  9.2
#                 103  8.2
#             7   101  9.1
#                 102  8.1

# %%
ah.xs("EE",axis=0,level='Dep')
# Out:
#                  SPI
# Col     Sem RN
# ABC     5   101  5.6
#             102  6.7
#         7   101  5.6
# Darshan 5   101  8.1
#             102  9.2
#             103  8.2
#         7   101  9.1
#             102  8.1

# %%
ah.xs("cE",axis=0,level='Dep')[ah>=7.5][102].dropn
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cE'
#
# The above exception was the direct cause of the following exception:
#
# ...
