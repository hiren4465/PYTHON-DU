# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
pythonmarks = [23,20,30,2,10,28,27,1,15]
pythonmarks2 = [30,30,10,21,10,28,24,12,25]
np.random.seed(121)
pythonmarks3 = np.random.randint(1,31,58)
pythonmarks3
# Out:
# array([ 3, 22,  9, 21,  2, 21, 20,  1, 15,  3, 21, 29, 23,  4, 10, 21, 26,
#        12, 16, 25,  7,  8, 22, 10, 10, 24, 20, 21, 14, 25, 20, 21, 11,  4,
#         5, 19, 15, 24, 24, 13, 23, 15,  5,  5, 10, 14, 29, 25, 13, 17,  8,
#         8,  2, 20, 13,  3, 30,  2])

# %%
rollno= [i for i in range(101,159)]
np.random.seed(120)
pythonmarks4 = np.random.randint(1,31,58)

# %%
# plt.plot(rollno,pythonmarks)
# plt.show() #open in bottom

# %%
# %matplotlib qt
# # open in application 
# plt.plot(rollno,pythonmarks)
# # plt.show()

# %%
# %matplotlib inline
# plt.plot(rollno,pythonmarks)
# plt.show() 
# # open in bottom

# %%
# %matplotlib inline
# plt.plot(rollno,pythonmarks)
# plt.plot(rollno,pythonmarks2)

# #multiple line data show
# #plt.show() 
# plt.savefig('demoplot.pdf',format="pdf")


# #when we use show function then do not save the figure in file
# #you can only show otherwise save the file

# %%
# %matplotlib inline
plt.plot(rollno,pythonmarks3)
plt.plot(rollno,pythonmarks4)

#multiple line data show
#plt.show() 
plt.savefig('demoplot.pdf',format="pdf")


#when we use show function then do not save the figure in file
#you can only show otherwise save the file

# %%
# %matplotlib qt

a= plt.axes()

a.set_xlim(100,200)
a.set_ylim(0,100)
a.set_xticks(range(101,201,2))
# set the gape of x with print

plt.plot(rollno,pythonmarks3)
plt.plot(rollno,pythonmarks4)

#multiple line data show
#plt.show() 
plt.savefig('demoplot.pdf',format="pdf")


#when we use show function then do not save the figure in file
#you can only show otherwise save the file

# %%
# %matplotlib qt

a= plt.axes()

a.set_xlim(100,200)
a.set_ylim(0,100)


# set the gape of x with print

plt.plot(rollno,pythonmarks3,ls="-",)
plt.plot(rollno,pythonmarks4)

#multiple line data show
#plt.show() 
# plt.savefig('demoplot.pdf',format="pdf")
plt.show()


#when we use show function then do not save the figure in file
#you can only show otherwise save the file

# %%
# %matplotlib inline



# set the gape of x with print

plt.plot(rollno,pythonmarks3,ls="--",)
plt.plot(rollno,pythonmarks4)

#multiple line data show
#plt.show() 
# plt.savefig('demoplot.pdf',format="pdf")
plt.show()


#when we use show function then do not save the figure in file
#you can only show otherwise save the file

# %%
# %matplotlib inline
plt.plot(rollno,pythonmarks3,ls="--",c="m",marker="x")
plt.plot(rollno,pythonmarks4)
plt.show()

# %%
# %matplotlib inline
plt.plot(rollno,pythonmarks3,ls="--",c="m",marker="x")
plt.plot(rollno,pythonmarks4)
plt.xlabel("Roll No")
plt.ylabel("Python marks")
plt.show()

# %%
# %matplotlib inline
plt.plot(rollno,pythonmarks3,ls="--",c="m",marker="x")
plt.plot(rollno,pythonmarks4)
plt.xlabel("Roll No")
plt.ylabel("Python marks")
plt.legend(['p1','p2'])
plt.show()

# %% [markdown]
# <h1>choosing the right graph</h1>

# %%
# Out:
#   Input In [15]
#     for i in range(1,101).shape(10,10)
#                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h1>Scater plot<h1/>
